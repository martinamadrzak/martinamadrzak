# %% [markdown]
# <a href="https://colab.research.google.com/github/martinamadrzak/martinamadrzak/blob/main/Week_2_Practice_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Week 2 Practice 1 - Assigning Variables, Data Types & Printing
# Data Types**
#
# This week, we learned about Python's basic, built-in data types.
#
# There are 4 "primitive", i.e., basic, data types that we will be using:
#
# * Integer - a whole number which can be positive, negative or zero; no
# decimal point
# * Floating point - any number which contains a decimal point
# * Boolean - logical which is either True or False
# * String - ordered sequence of characters
# plus one more advanced type called a **list**.
#
# If you want to determine what data type something is, you can just ask Python by using the command type ( ) To use this command, just put the item which you want to know its data type inside the parentheses.
#
# 1. Using the type() function determine the data type for 15
# 2. Using the type() function determine the data type for 21.65

# %%
type(15)
# Out:
# int

# %%
type(21.65)
# Out:
# float

# %% [markdown]
# **Defining a string**
#
# A string is an ordered sequence of characters (letters, numbers, etc). A string may be a single character or many characters. To tell Python that you are defining a string you must enclose it in parentheses and use quotes for the actual string (single or double but they must match). For example, my_school=("FSU")
#
# 1. Print out the data type for the string Goodnight All using the print() command
# 2. Define a string called animal containing the string lion and print out using print()

# %%
print("GoodNight All")
# Out:
# GoodNight All

# %%
animal = "lion"
print(animal)
# Out:
# lion

# %% [markdown]
# **Defining a list**
#
# A list is a data structure that is specific to Python and is not as basic as the other data types we have used. We will be using lists a lot this semester.
#
# To let Python know that you have a list you must enclose it in square brackets [ ] and the items must be separated by commas. The syntax for a list is [ item1, item2, ... ] The entries in a list can be any of the four basic data types or another list. Actually it can also contain other types of data structures which we haven't introduced yet. The items in a list are ordered.
#
# 1. Define a list called my_horses which contains the two strings Sonata and Ranger; print out using print()
# 2. Define \& print out a list containing the entries
#      16, 71.2 and the string January

# %%
my_horses = ["Sonata", "Ranger"]
print(my_horses)
# Out:
# ['Sonata', 'Ranger']

# %%
January = ["16, 71.2"]
print(January)

a_list = ["16", "71.2", "January"]
print(a_list)
# Out:
# ['16, 71.2']
# ['16', '71.2', 'January']

# %% [markdown]
# **Week 2 Practice 2 - Indexing with Strings and Lists**
#
# Defining a string or list
# This week, we learned about Python's basic, built-in data types.
#
# To define a string we surround the sequence of characters with quotes (single or double but they must match). To define a list we use square brackets [ ] with the items separated by commas.
#
# 1. Define a string using "Toy Story 4" and give it a name ; print it out
# 2. Define a list with the items "quizzes", .19, "homework", .15 ; give it a name and print it out

# %%
string = "Toy Story 4"
print(string)
# Out:
# Toy Story 4

# %%
list = ["quizzes", ".19", "homework", ".15"]
print(list)
# Out:
# ['quizzes', '.19', 'homework', '.15']

# %% [markdown]
# **Accessing an element of a string or list**
#
# Individual elements of a string or list can be accessed using Python's square-bracket notation. For example my_str[index of character]. So to access an element we need to know how Python defines the index of a character in a string or item in a list.
#
# Python **ALWAYS** indexes the first character in a string or the first item in a list as 0. So the second character/item is indexed as 1, the third as 2, etc. So to access the ith character in a string you use the index i-1. Python also allows negative indexing so the last item in a string or list has index = -1; the next to last has index = -2, etc.
#
# 1. Print out the third character ("y") in your string.
# 2. Print out the second item (.19) in your list.
# 3. Print out the last character ("4") in your string using negative indexing.
# 4. Print out the next to last item( "homework" ) in your list using negative indexing.
# 5. Print out the first item ("quizzes") in your list using negative indexing.

# %%
my_str = "Toy Story 4"
print(my_str[2])

list = ["quizzes", ".19", "homework", ".15"]
print(list[1])

my_str = "Toy Story 4"
print(my_str[-1])

list = ["quizzes", ".19", "homework", ".15"]
print(list[-2])

list = ["quizzes", ".19", "homework", ".15"]
print(list[0])
# Out:
# y
# .19
# 4
# homework
# quizzes

# %% [markdown]
# **Accessing a portion of a string or list**
#
# To access more than one character in a string or more than one item in a list we use the colon (:) notation. If we have an index followed by a colon then this gets the characters/items starting with the given index to the end of the string/list. If we have a colon followed by an index then this gets the characters/items starting with the first character/item followed by characters/items up to but not including the one with the given index. If we have two indices separated by a colon then we start with the character/item with the first index and end with the last character/item before the second index. Remember that if we have a colon followed by an index we don't include the character/item with this last index because it is up to but not including the character/item with the second index.
#
# 1. Print out the phrase Toy Story from your string using the colon notation.
# 2. For your list define a new list with the last two items ("homework", .15) using the colon notation and print out.
# 3. For your string print out the word Story.
# 4. Print out the second and third items in your list using the colon notation

# %%
my_str = "Toy Story 4"
print(my_str[0:11])

list = ["quizzes", ".19", "homework", ".15"]
print(list[2:])

my_str = "Toy Story 4"
print(my_str[4:9])
# Out:
# Toy Story 4
# ['homework', '.15']
# Story

# %% [markdown]
# Lists can be changed, strings can not.
#
# 1. Change the last item in your list to .18 and print out the modified list.
# 2. Try to change the last character in your string to "3"

# %%
list = ["quizzes", ".19", "homework", ".18"]
print(list[2:])
# Out:
# ['homework', '.18']

# %%
my_str = "Toy Story 3"
print(my_str[0:11])
# Out:
# Toy Story 3

# %% [markdown]
# **Week 2 Practice 3: Methods and Functions for Strings & Lists**
#
# In the previous notebooks we saw that the syntax is different for a function than for a method. In general, the syntax for a function is
#
# function_name( arguments )
# whereas when we use a method for a list we use the syntax
#
# listname.methodname ( arguments )
# Some methods don't have any arguments.

# %% [markdown]
# **Methods for Strings**
# Define a string "It was the best of times"
#
# 1. Use the upper method to print out the string all in upper case
# 2. Use the split method to create a list with just the separate words in it; print out. The default character to split a string by is the space; otherwise you put the character as an argument.
# 3. Make a list of all characters in your string formed by omitting the "t"; remember to put the separating character in quotes.

# %%
my_string = "It was the best of times"
print(my_string.upper())

my_string = "It was the best of times"
print(my_string.split())

my_string = "It was the best of times"
print(my_string.split("t"))
# Out:
# IT WAS THE BEST OF TIMES
# ['It', 'was', 'the', 'best', 'of', 'times']
# ['I', ' was ', 'he bes', ' of ', 'imes']

# %% [markdown]
# **List Functions**
#
# For lists containing numerical values we can use the function ```max``` to find the maximum value in a list and ```min``` to find the minimum value. You can also sum  the values in your list using the function ```sum```.
#
# Create a list with both positive and negative integers
# 1. Print out its maximum value.
# 2. Print out its maximum value.
# 3. Print out the sum of all the numbers in the list

# %%
list_strings = ["1", "2", "3", "4"]

print(max(list_strings))
print(min(list_strings))

list_of_integers = [int(x) for x in list_strings]
print(sum(list_of_integers))
# Out:
# 4
# 1
# 10

# %% [markdown]
# **List Methods**
#
# There are several methods for lists that are useful:
# * append
# * pop
# * remove
# * insert
# * copy
# * index
# The difference in pop and remove is that pop removes the last item and remove is for deleting an item by its name (such as 17 or 'FSU')
#
# 1. Append the string FSU to the end of the given list; print out the list
# 2. Create a new list list2 using copy and then remove the 2 strings from it; print out.

# %%
list1 = [ 4.5, 7.1, 'Seminoles']
list1.append("FSU")
print(list1)

list2 = [ 4.5, 7.1, 'Seminoles']
list2.remove("Seminoles")
list2.remove(7.1)
print(list2)
# Out:
# [4.5, 7.1, 'Seminoles', 'FSU']
# [4.5]

# %% [markdown]
# The method insert has two arguments; the first is the index where you want to put the item and the second is the item itself. For remove you just give the item you want removed.
#
# I have defined a list of colors.
#
# 1. Remove indigo from the list and print out.
# 2. Add green as the fourth item in the list and print out.
# 3. Put indigo back into the list in the correct location.

# %%
colors = [ 'red', 'orange', 'yellow', 'blue', 'indigo', 'violet']
colors.remove("indigo")
print(colors)

colors.insert(3, "green")
print(colors)

colors.insert(4, "indigo")
print(colors)
# Out:
# ['red', 'orange', 'yellow', 'blue', 'violet']
# ['red', 'orange', 'yellow', 'green', 'blue', 'violet']
# ['red', 'orange', 'yellow', 'green', 'indigo', 'blue', 'violet']

# %% [markdown]
# Sometimes we want to know the index where a particular item is located, such as the maximum of a list. To do this use the method .index(). For example if you want to know the index of "yellow" in the colors list above, then use colors.index('yellow')
#
# 1. With the given list print out the index where 17 appears. Use a f-formatted print statement.
# 2. With the given list print out the index where the minimum occurs.Use a f-formatted print statement.

# %%
list3 = [14, 21, 17, 2, 6]

print(f"The index of 17 is {list3.index(17)}")
print(f"The index of the minimum is {list3.index(min(list3))}")
# Out:
# The index of 17 is 2
# The index of the minimum is 3

# %% [markdown]
# **Creating a list iteratively**
#
# Many times we will be creating a list with a loop.  We will use the ```append``` method to do this but we must initialize our list first with the statement ```my_list=[]```
#
# 1. Initialize a list called prime
# 2. Add the number 11,13 to the list and print out.

# %%
my_list = ["prime"]
print(my_list)

my_list.insert(11,13)
print(my_list)
# Out:
# ['prime']
# ['prime', 13]
